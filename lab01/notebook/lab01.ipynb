# %% [markdown]
# # World Health Organization Data
#
# ## Global Health Observatory
#
# * [Data query API](https://apps.who.int/gho/data/node.resources.api)
# * [GHO OData API ](https://www.who.int/data/gho/info/gho-odata-api)
#
# Para se determinar o tipo de informação para acesso veja a [lista de dimensões e códigos](https://apps.who.int/gho/athena/api/GHO). Utilize o código disponível no campo `<Code label="">`. Por exemplo, no campo `<Code Label="WHOSIS_000001">` é possível encontrar o código `WHOSIS_000001` que indica `Life expectancy at birth (years)`.
#
# Depois de estabelecida a informação, podem ser configurados parâmetros, com o sufixo `?` depois da URL. Os parâmetros são separados por `?`.
#
# Os códigos dos países são encontrados em: [https://apps.who.int/gho/athena/api/COUNTRY](https://apps.who.int/gho/athena/api/COUNTRY).

# %% [markdown]
# ## Importando dados em JSON no Python
#
# ![JSON](https://github.com/santanche/lab2learn/blob/master/api/json.png?raw=1)

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
js = requests.get(url).content
print(js.decode("utf-8"))
# Out:
# {
# "copyright": "(c) World Health Organization",
# "dataset":
# [
# {
# "label": "CYCU",
# "display": "COUNTRY_YEARLY_CORE_UNITS"
# }
# ],
# "attribute":
# [
# {
# "label": "DS",
# "display": "DS"
# },
# {
# "label": "FIPS",
# "display": "FIPS"
# },
# {
# "label": "IOC",
# "display": "IOC"
# },
# {
# "label": "ISO2",
# "display": "ISO2"
# },
# {
# "label": "ISO",
# "display": "ISO"
# },
# {
# "label": "ITU",
# "display": "ITU"
# },
# {
# "label": "MARC",
# "display": "MARC"
# },
# {
# "label": "WHO",
# "display": "WHO"
# },
# {
# "label": "WMO",
# "display": "WMO"
# },
# {
# "label": "GEOMETRY",
# "display": "GEOMETRY"
# },
# {
# "label": "MORT",
# "display": "MORT"
# },
# {
# "label": "LAND_AREA_KMSQ_2012",
# "display": "LAND_AREA_KMSQ_2012"
# },
# {
# "label": "LANGUAGES_EN_2012",
# "display": "LANGUAGES_EN_2012"
# },
# {
# "label": "WHO_REGION",
# "display": "WHO_REGION"
# },
# {
# "label": "WHO_REGION_CODE",
# "display": "WHO_REGION_CODE"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP",
# "display": "World Bank income group"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP_CODE",
# "display": "World Bank income group code"
# },
# {
# "label": "SHORTNAMEES",
# "display": "SHORTNAMEES"
# },
# {
# "label": "SHORTNAMEFR",
# "display": "SHORTNAMEFR"
# },
# {
# "label": "WHOLEGALSTATUS",
# "display": "WHOLEGALSTATUS"
# },
# {
# "label": "CATEGORY",
# "display": "Category"
# },
# {
# "label": "RENDERER_ID",
# "display": "Renderer ID"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR",
# "display": "World Bank income group GNI reference year"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP_RELEASE_DATE",
# "display": "World Bank income group release date"
# },
# {
# "label": "DEFINITION_XML",
# "display": "Definition (XML)"
# },
# {
# "label": "DISPLAY_FR",
# "display": "Français"
# },
# {
# "label": "DISPLAY_ES",
# "display": "Español"
# }
# ],
# "dimension":
# [
# {
# "label": "GHO",
# "display": "Indicator",
# "isMeasure": true,
# "code":
# [
# {
# "label": "WHOSIS_000001",
# "display": "Life expectancy at birth (years)",
# "display_sequence": 10,
# "url": "https://www.who.int/data/gho/indicator-metadata-registry/imr-details/65",
# "attr":
# [
# {
# "category": "DISPLAY_FR",
# "value": "Esperance de vie a la naissance (ans)"
# },
# {
# "category": "DISPLAY_ES",
# "value": "Esperanza de vida al nacer"
# },
# {
# "category": "DEFINITION_XML",
# "value": "http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=65"
# },
# {
# "category": "CATEGORY",
# "value": "Sustainable development goals"
# },
# {
# "category": "RENDERER_ID",
# "value": "RENDER_2"
# }
# ]
# }
# ]
# },
# {
# "label": "PUBLISHSTATE",
# "display": "PUBLISH STATES",
# "isMeasure": false,
# "code":
# [
# {
# "label": "PUBLISHED",
# "display": "Published",
# "display_sequence": 0,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# },
# {
# "label": "YEAR",
# "display": "Year",
# "isMeasure": false,
# "code":
# [
# {
# "label": "2000",
# "display": "2000",
# "display_sequence": 79998000,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2001",
# "display": "2001",
# "display_sequence": 79987999,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2002",
# "display": "2002",
# "display_sequence": 79977998,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2003",
# "display": "2003",
# "display_sequence": 79967997,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2004",
# "display": "2004",
# "display_sequence": 79957996,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2005",
# "display": "2005",
# "display_sequence": 79947995,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2006",
# "display": "2006",
# "display_sequence": 79937994,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2007",
# "display": "2007",
# "display_sequence": 79927993,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2008",
# "display": "2008",
# "display_sequence": 79917992,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2009",
# "display": "2009",
# "display_sequence": 79907991,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2010",
# "display": "2010",
# "display_sequence": 79897990,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2011",
# "display": "2011",
# "display_sequence": 79887989,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2012",
# "display": "2012",
# "display_sequence": 79877988,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2013",
# "display": "2013",
# "display_sequence": 79867987,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2015",
# "display": "2015",
# "display_sequence": 79847985,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2014",
# "display": "2014",
# "display_sequence": 79857986,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2016",
# "display": "2016",
# "display_sequence": 79837984,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# },
# {
# "label": "REGION",
# "display": "WHO region",
# "isMeasure": false,
# "code":
# [
# {
# "label": "AMR",
# "display": "Americas",
# "display_sequence": 20,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# },
# {
# "label": "COUNTRY",
# "display": "Country",
# "isMeasure": false,
# "code":
# [
# {
# "label": "BRA",
# "display": "Brazil",
# "display_sequence": 240,
# "url": "",
# "attr":
# [
# {
# "category": "WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR",
# "value": "2017"
# },
# {
# "category": "WORLD_BANK_INCOME_GROUP_RELEASE_DATE",
# "value": "2018"
# },
# {
# "category": "LAND_AREA_KMSQ_2012",
# "value": "8,459,420"
# },
# {
# "category": "LANGUAGES_EN_2012",
# "value": "Portuguese"
# },
# {
# "category": "WHO_REGION",
# "value": "Americas"
# },
# {
# "category": "WORLD_BANK_INCOME_GROUP",
# "value": "Upper middle income"
# },
# {
# "category": "WHO_REGION_CODE",
# "value": "AMR"
# },
# {
# "category": "WORLD_BANK_INCOME_GROUP_CODE",
# "value": "WB_UMI"
# },
# {
# "category": "SHORTNAMEES",
# "value": "Brasil"
# },
# {
# "category": "SHORTNAMEFR",
# "value": "Brésil"
# },
# {
# "category": "WHOLEGALSTATUS",
# "value": "M"
# },
# {
# "category": "DS",
# "value": "BR"
# },
# {
# "category": "FIPS",
# "value": "BR"
# },
# {
# "category": "IOC",
# "value": "BRA"
# },
# {
# "category": "ISO2",
# "value": "BR"
# },
# {
# "category": "ISO",
# "value": "BRA"
# },
# {
# "category": "ITU",
# "value": "B"
# },
# {
# "category": "MARC",
# "value": "bl"
# },
# {
# "category": "WHO",
# "value": "BRA"
# },
# {
# "category": "WMO",
# "value": "BZ"
# },
# {
# "category": "GEOMETRY",
# "value": "BRA"
# },
# {
# "category": "MORT",
# "value": "2070"
# }
# ]
# }
# ]
# },
# {
# "label": "SEX",
# "display": "Sex",
# "isMeasure": false,
# "code":
# [
# {
# "label": "MLE",
# "display": "Male",
# "display_sequence": 2,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "FMLE",
# "display": "Female",
# "display_sequence": 3,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "BTSX",
# "display": "Both sexes",
# "display_sequence": 1,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# }
# ],
# "fact":
# [
# {
# "fact_id": 18157684,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2000"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "66.1",
# "numeric": 66.07471,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157685,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2001"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "66.5",
# "numeric": 66.52457,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157686,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "YEAR",
# "code": "2002"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "66.9",
# "numeric": 66.91918,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157687,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2003"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "67.3",
# "numeric": 67.29173,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157688,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2004"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "MLE"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "67.6",
# "numeric": 67.60056,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157689,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2005"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "68.4",
# "numeric": 68.37924,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157690,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "YEAR",
# "code": "2006"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "68.7",
# "numeric": 68.73450,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157691,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2007"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "MLE"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "69.1",
# "numeric": 69.08048,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157692,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "YEAR",
# "code": "2008"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "69.3",
# "numeric": 69.28578,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157693,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2009"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "69.5",
# "numeric": 69.52082,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157694,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "YEAR",
# "code": "2010"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "69.7",
# "numeric": 69.65516,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157695,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2011"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "69.9",
# "numeric": 69.94624,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157696,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2012"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "70.4",
# "numeric": 70.35987,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157697,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "YEAR",
# "code": "2013"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "70.7",
# "numeric": 70.65484,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157698,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2014"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "71.0",
# "numeric": 71.01771,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157699,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2015"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "71.2",
# "numeric": 71.18656,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157700,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "YEAR",
# "code": "2016"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "71.4",
# "numeric": 71.44357,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157702,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2000"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "73.9",
# "numeric": 73.90521,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157703,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2001"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "74.4",
# "numeric": 74.38860,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157704,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "YEAR",
# "code": "2002"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "74.7",
# "numeric": 74.69605,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157705,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2003"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "75.1",
# "numeric": 75.07509,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157706,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "YEAR",
# "code": "2004"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "75.3",
# "numeric": 75.31032,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157707,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2005"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "76.0",
# "numeric": 75.96941,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157708,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2006"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "76.2",
# "numeric": 76.22217,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157709,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2007"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "76.6",
# "numeric": 76.57856,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157710,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2008"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "76.8",
# "numeric": 76.83010,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157711,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2009"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "77.0",
# "numeric": 76.98610,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157712,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2010"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "77.1",
# "numeric": 77.12752,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157713,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2011"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "77.3",
# "numeric": 77.34761,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157714,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2012"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "77.8",
# "numeric": 77.80472,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157715,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2013"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "78.1",
# "numeric": 78.11185,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157716,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "YEAR",
# "code": "2014"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "78.5",
# "numeric": 78.47605,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157717,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "YEAR",
# "code": "2015"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "78.6",
# "numeric": 78.62926,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157718,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2016"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "78.9",
# "numeric": 78.88345,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157720,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "YEAR",
# "code": "2000"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "69.9",
# "numeric": 69.89580,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157721,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "70.4",
# "numeric": 70.36314,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157722,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2002"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "70.7",
# "numeric": 70.72389,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157723,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2003"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "71.1",
# "numeric": 71.09914,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157724,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2004"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "71.4",
# "numeric": 71.37670,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157725,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "YEAR",
# "code": "2005"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "72.1",
# "numeric": 72.11478,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157726,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2006"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "72.4",
# "numeric": 72.42526,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157727,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2007"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "72.8",
# "numeric": 72.77940,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157728,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2008"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "73.0",
# "numeric": 73.00681,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157729,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "YEAR",
# "code": "2009"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "73.2",
# "numeric": 73.20933,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157730,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2010"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "73.3",
# "numeric": 73.34766,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157731,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2011"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "73.6",
# "numeric": 73.60731,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157732,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "YEAR",
# "code": "2012"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "74.0",
# "numeric": 74.04764,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157733,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2013"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "74.3",
# "numeric": 74.34875,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157734,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2014"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "74.7",
# "numeric": 74.71724,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157735,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2015"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "74.9",
# "numeric": 74.88107,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 18157736,
# "dataset": "CYCU",
# "effective_date": "2018-04-06",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2016"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "comments": "WHO life table method: Vital registration",
# "value":
# {
# "display": "75.1",
# "numeric": 75.13705,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# }
# ]
# }

# %% [markdown]
# ## Importando dados em CSV no Python
#
# ![CSV](https://github.com/santanche/lab2learn/blob/master/api/csv.png?raw=1)

# %%
import pandas as pd
import io
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
#               GHO PUBLISHSTATE  ...  High                                   Comments
# 0   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 1   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 2   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 3   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 4   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 5   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 6   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 7   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 8   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 9   WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 10  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 11  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 12  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 13  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 14  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 15  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 16  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 17  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 18  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 19  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 20  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 21  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 22  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 23  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 24  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 25  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 26  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 27  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 28  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 29  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 30  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 31  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 32  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 33  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 34  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 35  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 36  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 37  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 38  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 39  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 40  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 41  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 42  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 43  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 44  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 45  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 46  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 47  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 48  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 49  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
# 50  WHOSIS_000001    PUBLISHED  ...   NaN  WHO life table method: Vital registration
#
# [51 rows x 11 columns]

# %% [markdown]
# # Importando dados em XML no Python
#
# ![XML](https://github.com/santanche/lab2learn/blob/master/api/xml.png?raw=1)

# %%
import io
import requests
import xml.etree.ElementTree as et
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA"
data = requests.get(url).content
x = et.parse(io.StringIO(data.decode("utf-8")))
print(x)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x7f16e22b8048>

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import pandas as pd
import io
import requests
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv.head())
# Out:
#           date_of_interest  case_count  hospitalized_count  death_count
# 0  2020-02-29T00:00:00.000           1                  11            0
# 1  2020-03-01T00:00:00.000           0                   4            0
# 2  2020-03-02T00:00:00.000           0                  21            0
# 3  2020-03-03T00:00:00.000           2                  20            0
# 4  2020-03-04T00:00:00.000           5                  22            0

# %%
import io
import requests
import json
url = "https://api.covid19api.com/summary"
response = requests.get(url).content
js = json.loads(response) #Passa o Json para dicionário.
print("Json inteiro:")
print(js)
print("Acessando o campo 'Global:NewConfirmed' do json:")
print(f"Novos casos global: {js['Global']['NewConfirmed']}")
# Out:
# Json inteiro:
# {'Message': '', 'Global': {'NewConfirmed': 278043, 'TotalConfirmed': 30772545, 'NewDeaths': 5209, 'TotalDeaths': 956915, 'NewRecovered': 237806, 'TotalRecovered': 21013429}, 'Countries': [{'Country': 'Afghanistan', 'CountryCode': 'AF', 'Slug': 'afghanistan', 'NewConfirmed': 36, 'TotalConfirmed': 38919, 'NewDeaths': 0, 'TotalDeaths': 1437, 'NewRecovered': 0, 'TotalRecovered': 32576, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Albania', 'CountryCode': 'AL', 'Slug': 'albania', 'NewConfirmed': 153, 'TotalConfirmed': 12226, 'NewDeaths': 5, 'TotalDeaths': 358, 'NewRecovered': 57, 'TotalRecovered': 6888, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Algeria', 'CountryCode': 'DZ', 'Slug': 'algeria', 'NewConfirmed': 210, 'TotalConfirmed': 49623, 'NewDeaths': 6, 'TotalDeaths': 1665, 'NewRecovered': 105, 'TotalRecovered': 34923, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Andorra', 'CountryCode': 'AD', 'Slug': 'andorra', 'NewConfirmed': 0, 'TotalConfirmed': 1564, 'NewDeaths': 0, 'TotalDeaths': 53, 'NewRecovered': 0, 'TotalRecovered': 1164, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Angola', 'CountryCode': 'AO', 'Slug': 'angola', 'NewConfirmed': 53, 'TotalConfirmed': 3901, 'NewDeaths': 0, 'TotalDeaths': 147, 'NewRecovered': 2, 'TotalRecovered': 1445, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Antigua and Barbuda', 'CountryCode': 'AG', 'Slug': 'antigua-and-barbuda', 'NewConfirmed': 1, 'TotalConfirmed': 96, 'NewDeaths': 0, 'TotalDeaths': 3, 'NewRecovered': 0, 'TotalRecovered': 92, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Argentina', 'CountryCode': 'AR', 'Slug': 'argentina', 'NewConfirmed': 9276, 'TotalConfirmed': 622934, 'NewDeaths': 143, 'TotalDeaths': 12799, 'NewRecovered': 10791, 'TotalRecovered': 478077, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Armenia', 'CountryCode': 'AM', 'Slug': 'armenia', 'NewConfirmed': 244, 'TotalConfirmed': 47154, 'NewDeaths': 2, 'TotalDeaths': 928, 'NewRecovered': 182, 'TotalRecovered': 42551, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Australia', 'CountryCode': 'AU', 'Slug': 'australia', 'NewConfirmed': 13, 'TotalConfirmed': 26898, 'NewDeaths': 5, 'TotalDeaths': 849, 'NewRecovered': 107, 'TotalRecovered': 23966, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Austria', 'CountryCode': 'AT', 'Slug': 'austria', 'NewConfirmed': 813, 'TotalConfirmed': 37474, 'NewDeaths': 2, 'TotalDeaths': 765, 'NewRecovered': 510, 'TotalRecovered': 28961, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Azerbaijan', 'CountryCode': 'AZ', 'Slug': 'azerbaijan', 'NewConfirmed': 148, 'TotalConfirmed': 39042, 'NewDeaths': 2, 'TotalDeaths': 574, 'NewRecovered': 177, 'TotalRecovered': 36601, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Bahamas', 'CountryCode': 'BS', 'Slug': 'bahamas', 'NewConfirmed': 37, 'TotalConfirmed': 3214, 'NewDeaths': 4, 'TotalDeaths': 73, 'NewRecovered': 53, 'TotalRecovered': 1679, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Bahrain', 'CountryCode': 'BH', 'Slug': 'bahrain', 'NewConfirmed': 620, 'TotalConfirmed': 64499, 'NewDeaths': 1, 'TotalDeaths': 221, 'NewRecovered': 599, 'TotalRecovered': 57299, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Bangladesh', 'CountryCode': 'BD', 'Slug': 'bangladesh', 'NewConfirmed': 1567, 'TotalConfirmed': 347372, 'NewDeaths': 32, 'TotalDeaths': 4913, 'NewRecovered': 2051, 'TotalRecovered': 254386, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Barbados', 'CountryCode': 'BB', 'Slug': 'barbados', 'NewConfirmed': 0, 'TotalConfirmed': 185, 'NewDeaths': 0, 'TotalDeaths': 7, 'NewRecovered': 0, 'TotalRecovered': 172, 'Date': '2020-09-20T19:34:52Z', 'Premium': {}}, {'Country': 'Belarus', 'CountryCode': 'BY', 'Slug': 'belarus', 'NewConfirmed': 231, 'TotalConfirmed': 75461, 'NewDeaths': 3, 'TotalDeaths': 776, 'NewRecovered': 114, 'TotalRecovered': 73212, 'Date': '202 ...
# Acessando o campo 'Global:NewConfirmed' do json:
# Novos casos global: 278043

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.

# %% [markdown]
# ![legenda](../images/diagrama.jpeg)
